# %%
import numpy as np
import json
import cvxpy as cp
from scipy import sparse as sp
import scipy.special as sps
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
from time import time
import math

from src.problems.utils import sample_data_for_group
from src.problems.problems import compute_producer_optimal_solution, _compute_consumer_optimal_solution_cvar_relaxed_base, _compute_consumer_optimal_solution_cvar
from src.problems.gradient_problem import compute_consumer_optimal_solution_cvar_grad, compute_consumer_optimal_with_augmented_lagrangian_cvar

import warnings
warnings.filterwarnings("ignore")

# %%
def _compute_consumer_optimal_solution_cvar_relaxed_topk_rounding(
    allocations: np.ndarray,
    k_rec: int,
) -> tuple[float, np.ndarray]:
    idxs = allocations.argsort(axis=1)[:, -k_rec:]
    alls = np.zeros_like(allocations)
    alls[np.arange(allocations.shape[0])[:, None], idxs] = 1

    return alls

def _compute_consumer_optimal_solution_cvar_relaxed_naive_rounding(
    allocations: np.ndarray,
) -> tuple[float, np.ndarray]:
    alls = allocations.round().astype(int)

    return alls

def _compute_consumer_optimal_solution_cvar_relaxed_probabilistic_rounding(
    allocations: np.ndarray,
) -> tuple[float, np.ndarray]:
    rounds = 100
    alls = []
    for _ in range(rounds):
        alls.append(np.random.binomial(1, allocations).astype(int))

    return np.mean(alls, axis=0).round().astype(int)

# %%
# load data
with open("../../data/amazon_predictions.npy", "rb") as f:
    REL_MATRIX = np.load(f)

with open("../../data/amazon_user_groups.json", "r") as f:
    GROUPS_MAP = json.load(f)

# %%
N_CONSUMERS = 300
N_PRODUCERS = 300
ALPHA = 0.5
GAMMA = 0.5
GROUP_KEY = "top_category"
K_REC = 10
SOLVER = cp.GUROBI

# %%
def compute_perc_prod_below_threshold(
    allocation: np.ndarray,
    threshold: float,
) -> float:
    producer_allocations = allocation.sum(axis=0)
    num_of_producers_below_threshold = np.sum(producer_allocations < threshold)
    return num_of_producers_below_threshold / len(producer_allocations)

def compute_mean_prod_below_threshold(
    allocation: np.ndarray,
    threshold: float,
) -> float:
    producer_allocations = allocation.sum(axis=0)
    return np.mean(math.ceil(threshold) - producer_allocations[producer_allocations < threshold])

def compute_mean_consumer_utility(
    allocation: np.ndarray,
    rel_matrix: np.ndarray,
) -> float:
    return (allocation * rel_matrix).sum() / allocation.sum()

def compute_perc_cons_above_threshold(
    allocation: np.ndarray,
    k_rec: int
) -> float:
    consumer_allocations = allocation.sum(axis=1)
    num_of_consumers_above_threshold = np.sum(consumer_allocations > k_rec)
    return num_of_consumers_above_threshold / len(consumer_allocations)

def compute_perc_cons_below_threshold(
    allocation: np.ndarray,
    k_rec: int
) -> float:
    consumer_allocations = allocation.sum(axis=1)
    num_of_consumers_below_threshold = np.sum(consumer_allocations < k_rec)
    return num_of_consumers_below_threshold / len(consumer_allocations)

def compute_mean_cons_above_threshold(
    allocation: np.ndarray,
    k_rec: int
) -> float:
    consumer_allocations = allocation.sum(axis=1)
    return np.mean(k_rec - consumer_allocations[consumer_allocations > k_rec])


def compute_mean_cons_below_threshold(
    allocation: np.ndarray,
    k_rec: int
) -> float:
    consumer_allocations = allocation.sum(axis=1)
    return np.mean(k_rec - consumer_allocations[consumer_allocations < k_rec])

def compute_var_between_groups(allocations: np.ndarray, group_assignments: np.ndarray) -> float:
    unique_groups, group_indices = np.unique(group_assignments, return_inverse=True)
    num_groups = len(unique_groups)
    group_masks = [group_indices == i for i in range(num_groups)]
    group_sizes = np.array([mask.sum() for mask in group_masks])

    means = []
    for mask, size in zip(group_masks, group_sizes):
        group_alloc = allocations[mask]
        mean = np.mean(group_alloc.sum(axis=0))
        means.append(mean)

    return np.var(means)

# %%
results = []

for size in [200, 500]:
    print(f"Running for size {size}")
    for k_rec in [10, 15, 25]:
        print(f"Running for k_rec {k_rec}")
        for run in range(3):
            rel_matrix_sampled, consumer_ids, group_assignments = sample_data_for_group(
                n_consumers=size,
                n_producers=size,
                groups_map=GROUPS_MAP,
                group_key=GROUP_KEY,
                data=REL_MATRIX,
                naive_sampling=True,
                seed=run**2,
            )
            producer_max_min_utility, _ = compute_producer_optimal_solution(
                rel_matrix=rel_matrix_sampled,
                k_rec=k_rec,
                solver=SOLVER,
            )
            start_time = time()
            _, optimal_allocation = _compute_consumer_optimal_solution_cvar(
                rel_matrix=rel_matrix_sampled,
                k_rec=k_rec,
                producer_max_min_utility=producer_max_min_utility,
                gamma=GAMMA,
                group_assignments=group_assignments,
                alpha=ALPHA,
                solver=SOLVER,
            )
            optimal_time = time() - start_time

            start_time = time()
            _, _base_cvar_allocation = _compute_consumer_optimal_solution_cvar_relaxed_base(
                rel_matrix=rel_matrix_sampled,
                k_rec=k_rec,
                producer_max_min_utility=producer_max_min_utility,
                gamma=GAMMA,
                group_assignments=group_assignments,
                alpha=ALPHA,
                solver=SOLVER,
            )
            relaxed_time = time() - start_time

            rounded_cvar_allocation = _compute_consumer_optimal_solution_cvar_relaxed_naive_rounding(
                allocations=_base_cvar_allocation,
            )
            prob_cvar_allocation = _compute_consumer_optimal_solution_cvar_relaxed_probabilistic_rounding(
                allocations=_base_cvar_allocation,
            )
            topk_cvar_allocation = _compute_consumer_optimal_solution_cvar_relaxed_topk_rounding(
                allocations=_base_cvar_allocation,
                k_rec=k_rec,
            )

            start_time = time()
            _base_cvar_grad_allocations, _ = compute_consumer_optimal_solution_cvar_grad(
                rel_matrix=rel_matrix_sampled,
                k_rec=k_rec,
                producer_max_min_utility=producer_max_min_utility,
                gamma=GAMMA,
                group_assignments=group_assignments,
                alpha=ALPHA,
                hidden_dim=size * 2,
                max_epochs=100000,
                patience_delta=1e-5,
                max_patience=10,
                verbose=False,
            )
            grad_time = time() - start_time

            rounded_cvar_grad_allocation = _compute_consumer_optimal_solution_cvar_relaxed_naive_rounding(
                allocations=_base_cvar_grad_allocations,
            )
            prob_cvar_grad_allocation = _compute_consumer_optimal_solution_cvar_relaxed_probabilistic_rounding(
                allocations=_base_cvar_grad_allocations,
            )
            topk_cvar_grad_allocation = _compute_consumer_optimal_solution_cvar_relaxed_topk_rounding(
                allocations=_base_cvar_grad_allocations,
                k_rec=k_rec,
            )

            start_time = time()
            _base_cvar_lang_allocation  = compute_consumer_optimal_with_augmented_lagrangian_cvar(
                k_rec=k_rec,
                rel_matrix=rel_matrix_sampled,
                producer_max_min_utility=producer_max_min_utility,
                gamma=GAMMA,
                group_assignments=group_assignments,
                alpha_cvar=ALPHA,
                verbose=False,
                max_epochs=100000,
                patience_delta=1e-5,
                max_patience=10,
            )
            lang_time = time() - start_time
            rounded_cvar_lang_allocation = _compute_consumer_optimal_solution_cvar_relaxed_naive_rounding(
                allocations=_base_cvar_lang_allocation,
            )
            prob_cvar_lang_allocation = _compute_consumer_optimal_solution_cvar_relaxed_probabilistic_rounding(
                allocations=_base_cvar_lang_allocation,
            )
            topk_cvar_lang_allocation = _compute_consumer_optimal_solution_cvar_relaxed_topk_rounding(
                allocations=_base_cvar_lang_allocation,
                k_rec=k_rec,
            )


            stats = {}
            for allocation, method in zip(
                [optimal_allocation, rounded_cvar_allocation, topk_cvar_allocation, rounded_cvar_grad_allocation, topk_cvar_grad_allocation, rounded_cvar_lang_allocation, topk_cvar_lang_allocation, prob_cvar_allocation, prob_cvar_grad_allocation, prob_cvar_lang_allocation],
                ["Baseline", "LP Round", "LP TopK", "Grad Round", "Grad TopK", "Lang Round", "Lang TopK", "Prob Round", "Prob Grad", "Prob Lang"]
            ):
                stats["$\mathbb{E}[{U_{C}}]$_" + method] = compute_mean_consumer_utility(
                    allocation=allocation,
                    rel_matrix=rel_matrix_sampled,
                )
                stats["$\sigma(\mathbb{E}[U_{G}])$_" + method] = compute_var_between_groups(
                    allocations=allocation,
                    group_assignments=group_assignments,
                )
                stats["$\#(U_{P} < U_{P\min})/N_{P}$_" + method] = compute_perc_prod_below_threshold(
                    allocation=allocation,
                    threshold=producer_max_min_utility * GAMMA,
                )
                stats["$\sum(V - U_{P})/N_{P^{b}}$_" + method] = compute_mean_prod_below_threshold(
                    allocation=allocation,
                    threshold=producer_max_min_utility * GAMMA,
                )
                stats["$\#(A_{C} > k)/N_{C}$_" + method] = compute_perc_cons_above_threshold(
                    allocation=allocation,
                    k_rec=k_rec,
                )
                stats["$\sum(A_{C} - k)/N_{A_{c}^{a}}$_" + method] = compute_mean_cons_above_threshold(
                    allocation=allocation,
                    k_rec=k_rec,
                )
                stats["$\#(A_{C} < k)/N_{C}$_" + method] = compute_perc_cons_below_threshold(
                    allocation=allocation,
                    k_rec=k_rec,
                )
                stats["$\sum(k - A_{C})/N_{A_{c}^{b}}$_" + method] = compute_mean_cons_below_threshold(
                    allocation=allocation,
                    k_rec=k_rec,
                )

            results.append({
                "$N_{c}$, N_{p}$": size,
                "k": k_rec,
                "optimal_time": optimal_time,
                "relaxed_time": relaxed_time,
                "grad_time": grad_time,
                **stats,
                })
# Out:
# Running for size 200
# Running for k_rec 10
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2653936
# Academic license 2653936 - for non-commercial use only - registered to do___@student.uva.nl
# Running for k_rec 15
# Running for k_rec 25
# Running for size 500
# Running for k_rec 10
# Running for k_rec 15
# Running for k_rec 25

# %%
df = pd.DataFrame(results)

# %%
import pandas as pd
import re
df = pd.read_csv("output.csv")

df.to_csv("output.csv", index=False)

# %%
df.columns
# rename $N_{c}$, N_{p}$ to $N_{c}, N_{p}$
df.rename(columns={"$N_{c}$, N_{p}$": "$N_{C}, N_{P}$"}, inplace=True)
df.columns
# Out:
# Index(['$N_{C}, N_{P}$', 'k', 'optimal_time', 'relaxed_time', 'grad_time',
#        '$\mathbb{E}[{U_{C}}]$_Baseline',
#        '$\sigma(\mathbb{E}[U_{G}])$_Baseline',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Baseline',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Baseline',
#        '$\#(A_{C} > k)/N_{C}$_Baseline',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Baseline',
#        '$\#(A_{C} < k)/N_{C}$_Baseline',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Baseline',
#        '$\mathbb{E}[{U_{C}}]$_LP Round',
#        '$\sigma(\mathbb{E}[U_{G}])$_LP Round',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_LP Round',
#        '$\sum(V - U_{P})/N_{P^{b}}$_LP Round',
#        '$\#(A_{C} > k)/N_{C}$_LP Round',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_LP Round',
#        '$\#(A_{C} < k)/N_{C}$_LP Round',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_LP Round',
#        '$\mathbb{E}[{U_{C}}]$_LP TopK', '$\sigma(\mathbb{E}[U_{G}])$_LP TopK',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_LP TopK',
#        '$\sum(V - U_{P})/N_{P^{b}}$_LP TopK', '$\#(A_{C} > k)/N_{C}$_LP TopK',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_LP TopK',
#        '$\#(A_{C} < k)/N_{C}$_LP TopK',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_LP TopK',
#        '$\mathbb{E}[{U_{C}}]$_Grad Round',
#        '$\sigma(\mathbb{E}[U_{G}])$_Grad Round',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Grad Round',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Grad Round',
#        '$\#(A_{C} > k)/N_{C}$_Grad Round',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Grad Round',
#        '$\#(A_{C} < k)/N_{C}$_Grad Round',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Grad Round',
#        '$\mathbb{E}[{U_{C}}]$_Grad TopK',
#        '$\sigma(\mathbb{E}[U_{G}])$_Grad TopK',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Grad TopK',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Grad TopK',
#        '$\#(A_{C} > k)/N_{C}$_Grad TopK',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Grad TopK',
#        '$\#(A_{C} < k)/N_{C}$_Grad TopK',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Grad TopK',
#        '$\mathbb{E}[{U_{C}}]$_Lang Round',
#        '$\sigma(\mathbb{E}[U_{G}])$_Lang Round',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Lang Round',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Lang Round',
#        '$\#(A_{C} > k)/N_{C}$_Lang Round',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Lang Round',
#        '$\#(A_{C} < k)/N_{C}$_Lang Round',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Lang Round',
#        '$\mathbb{E}[{U_{C}}]$_Lang TopK',
#        '$\sigma(\mathbb{E}[U_{G}])$_Lang TopK',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Lang TopK',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Lang TopK',
#        '$\#(A_{C} > k)/N_{C}$_Lang TopK',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Lang TopK',
#        '$\#(A_{C} < k)/N_{C}$_Lang TopK',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Lang TopK',
#        '$\mathbb{E}[{U_{C}}]$_Prob Round',
#        '$\sigma(\mathbb{E}[U_{G}])$_Prob Round',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Prob Round',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Prob Round',
#        '$\#(A_{C} > k)/N_{C}$_Prob Round',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Prob Round',
#        '$\#(A_{C} < k)/N_{C}$_Prob Round',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Prob Round',
#        '$\mathbb{E}[{U_{C}}]$_Prob Grad',
#        '$\sigma(\mathbb{E}[U_{G}])$_Prob Grad',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Prob Grad',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Prob Grad',
#        '$\#(A_{C} > k)/N_{C}$_Prob Grad',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Prob Grad',
#        '$\#(A_{C} < k)/N_{C}$_Prob Grad',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Prob Grad',
#        '$\mathbb{E}[{U_{C}}]$_Prob Lang',
#        '$\sigma(\mathbb{E}[U_{G}])$_Prob Lang',
#        '$\#(U_{P} < U_{P\min})/N_{P}$_Prob Lang',
#        '$\sum(V - U_{P})/N_{P^{b}}$_Prob Lang',
#        '$\#(A_{C} > k)/N_{C}$_Prob Lang',
#        '$\sum(A_{C} - k)/N_{A_{c}^{a}}$_Prob Lang',
#        '$\#(A_{C} < k)/N_{C}$_Prob Lang',
#        '$\sum(k - A_{C})/N_{A_{c}^{b}}$_Prob Lang'],
#       dtype='object')

# %%
GROUP_BY_COLS = ["$N_{C}, N_{P}$", "k"]
METHODS = ["Baseline", "LP Round", "LP TopK", "Grad Round", "Grad TopK", "Lang Round", "Lang TopK", "Prob Round", "Prob Grad", "Prob Lang"]
BASE_METRICS = [
    "$\mathbb{E}[{U_{C}}]$",
    "$\sigma(\mathbb{E}[U_{G}])$",
    "$\#(U_{P} < U_{P\min})/N_{P}$",
    "$\sum(V - U_{P})/N_{P^{b}}$",
    "$\#(A_{C} > k)/N_{C}$",
    "$\sum(A_{C} - k)/N_{A_{c}^{a}}$",
    "$\#(A_{C} < k)/N_{C}$",
    "$\sum(k - A_{C})/N_{A_{c}^{b}}$",
]

def aggregate_wide(df: pd.DataFrame):
    # build the dict of aggregations
    agg_dict = {
        f"{base}_{m}": ["mean", "std"]
        for m in METHODS
        for base in BASE_METRICS
    }
    # group and flatten the MultiIndex
    grouped = df.groupby(GROUP_BY_COLS).agg(agg_dict)
    # flatten columns: e.g. ("mean_consumer_utility_optimal","mean") → "mean_consumer_utility_optimal_mean"
    grouped.columns = [
        f"{col[0]}_{col[1]}" for col in grouped.columns
    ]
    return grouped.reset_index()

agg_df = aggregate_wide(df)

def aggregate_long(df: pd.DataFrame):
    # melt into a tall table
    value_vars = [
        f"{base}_{m}"
        for m in METHODS
        for base in BASE_METRICS
    ]
    df_long = df.melt(
        id_vars=GROUP_BY_COLS,
        value_vars=value_vars,
        var_name="metric_method",
        value_name="value",
    )
    method_pattern = "|".join(re.escape(m) for m in METHODS)
    extract_re = rf"(?P<metric>.*)_(?P<Method>{method_pattern})$"

    # do the extract:
    df_long[["metric", "Method"]] = df_long["metric_method"].str.extract(extract_re)
    # split “mean_consumer_utility_optimal” → (“mean_consumer_utility”, “optimal”)
    # now group
    return (
        df_long
        .groupby(GROUP_BY_COLS + ["Method", "metric"])["value"]
        .agg(mean="mean", std="std")
        .reset_index()
    )

agg_long_df = aggregate_long(df)

# 1) combine mean+std into one column
def fmt(x, y):
    if pd.isna(x):
        return "-"
    if pd.isna(y):
        y = 0.0
    return f"${x:.2f} \pm \\scriptstyle{{{y:.2f}}}$"

agg_long_df["mean_std"] = agg_long_df.apply(
    lambda row: fmt(row["mean"], row["std"]),
    axis=1
)

# 2) pivot so metrics become columns
pivot = (
    agg_long_df
    .pivot_table(
        index=["$N_{C}, N_{P}$", "k", "Method"],
        columns="metric",
        values="mean_std",
        aggfunc="first"
    )
    # flatten the column Index
    .rename_axis(None, axis=1)
    .reset_index()
)

# 3) export to LaTeX
latex = pivot.to_latex(
    index=False,
    na_rep="",
    column_format="lll" + "r" * (pivot.shape[1] - 3),
    longtable=False,
    caption="Performance by method and metric",
    label="tab:results",
    escape=False,
    bold_rows=False,
    multicolumn=True,
)

# add \resizebox{\textwidth}{!}{\begin{tabular}
latex = latex.replace(
    "\\begin{tabular}",
    "\\resizebox{\\textwidth}{!}{\\begin{tabular}"
).replace(
    "\\end{tabular}",
    "\\end{tabular}}"
)

print(latex)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\#'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\#'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\#'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\#'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\#'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\#'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:4: SyntaxWarning: invalid escape sequence '\m'
#   "$\mathbb{E}[{U_{C}}]$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:5: SyntaxWarning: invalid escape sequence '\s'
#   "$\sigma(\mathbb{E}[U_{G}])$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:6: SyntaxWarning: invalid escape sequence '\#'
#   "$\#(U_{P} < U_{P\min})/N_{P}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:7: SyntaxWarning: invalid escape sequence '\s'
#   "$\sum(V - U_{P})/N_{P^{b}}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:8: SyntaxWarning: invalid escape sequence '\#'
#   "$\#(A_{C} > k)/N_{C}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:9: SyntaxWarning: invalid escape sequence '\s'
#   "$\sum(A_{C} - k)/N_{A_{c}^{a}}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:10: SyntaxWarning: invalid escape sequence '\#'
#   "$\#(A_{C} < k)/N_{C}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:11: SyntaxWarning: invalid escape sequence '\s'
#   "$\sum(k - A_{C})/N_{A_{c}^{b}}$",
# /var/folders/9l/_y964wyn5fx6bcqmbqjpd9780000gp/T/ipykernel_22308/1463059658.py:66: SyntaxWarning: invalid escape sequence '\p'
#   return f"${x:.2f} \pm \\scriptstyle{{{y:.2f}}}$"
# \begin{table}
# \caption{Performance by method and metric}
# \label{tab:results}
# \resizebox{\textwidth}{!}{\begin{tabular}{lllrrrrrrrr}
# \toprule
# $N_{C}, N_{P}$ & k & Method & $\#(A_{C} < k)/N_{C}$ & $\#(A_{C} > k)/N_{C}$ & $\#(U_{P} < U_{P\min})/N_{P}$ & $\mathbb{E}[{U_{C}}]$ & $\sigma(\mathbb{E}[U_{G}])$ & $\sum(A_{C} - k)/N_{A_{c}^{a}}$ & $\sum(V - U_{P})/N_{P^{b}}$ & $\sum(k - A_{C})/N_{A_{c}^{b}}$ \\
# \midrule
# 200 & 10 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & - & - & - \\
# 200 & 10 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & - & - \\
# 200 & 10 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & - & - & - \\
# 200 & 10 & LP Round & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 10 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 10 & Lang Round & $0.02 \pm \scriptstyle{0.02}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 10 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.02 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 10 & Prob Grad & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & - & - \\
# 200 & 10 & Prob Lang & $0.07 \pm \scriptstyle{0.02}$ & $0.06 \pm \scriptstyle{0.02}$ & $0.08 \pm \scriptstyle{0.03}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.04 \pm \scriptstyle{0.08}$ & $1.02 \pm \scriptstyle{0.03}$ & $1.08 \pm \scriptstyle{0.07}$ \\
# 200 & 10 & Prob Round & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.38 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 15 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & - & - & - \\
# 200 & 15 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.91 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 15 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.91 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 15 & LP Round & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 15 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 15 & Lang Round & $0.02 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 15 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 15 & Prob Grad & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.91 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 15 & Prob Lang & $0.07 \pm \scriptstyle{0.01}$ & $0.06 \pm \scriptstyle{0.02}$ & $0.06 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.18 \pm \scriptstyle{0.24}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.11 \pm \scriptstyle{0.13}$ \\
# 200 & 15 & Prob Round & $0.01 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $0.85 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 25 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.36 \pm \scriptstyle{0.00}$ & - & - & - \\
# 200 & 25 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.36 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & - & - \\
# 200 & 25 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.36 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 25 & LP Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.36 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 200 & 25 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.36 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 25 & Lang Round & $0.05 \pm \scriptstyle{0.01}$ & $0.02 \pm \scriptstyle{0.01}$ & $0.04 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.35 \pm \scriptstyle{0.01}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.06 \pm \scriptstyle{0.10}$ \\
# 200 & 25 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.04 \pm \scriptstyle{0.01}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.36 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 200 & 25 & Prob Grad & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.36 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & - & - \\
# 200 & 25 & Prob Lang & $0.14 \pm \scriptstyle{0.02}$ & $0.08 \pm \scriptstyle{0.01}$ & $0.15 \pm \scriptstyle{0.02}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.34 \pm \scriptstyle{0.01}$ & $-1.30 \pm \scriptstyle{0.09}$ & $1.09 \pm \scriptstyle{0.02}$ & $1.17 \pm \scriptstyle{0.15}$ \\
# 200 & 25 & Prob Round & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.93 \pm \scriptstyle{0.00}$ & $2.36 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 10 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & - & - & - \\
# 500 & 10 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 10 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 10 & LP Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 10 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 10 & Lang Round & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 10 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 10 & Prob Grad & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 10 & Prob Lang & $0.06 \pm \scriptstyle{0.01}$ & $0.04 \pm \scriptstyle{0.00}$ & $0.07 \pm \scriptstyle{0.03}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.01 \pm \scriptstyle{0.01}$ & $1.09 \pm \scriptstyle{0.15}$ \\
# 500 & 10 & Prob Round & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.95 \pm \scriptstyle{0.00}$ & $0.35 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 15 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & - & - & - \\
# 500 & 15 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 15 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 15 & LP Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 15 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 15 & Lang Round & $0.02 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 15 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 15 & Prob Grad & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 15 & Prob Lang & $0.05 \pm \scriptstyle{0.02}$ & $0.03 \pm \scriptstyle{0.01}$ & $0.06 \pm \scriptstyle{0.02}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.09 \pm \scriptstyle{0.10}$ & $1.01 \pm \scriptstyle{0.02}$ & $1.09 \pm \scriptstyle{0.01}$ \\
# 500 & 15 & Prob Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $0.79 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 25 & Baseline & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.20 \pm \scriptstyle{0.00}$ & - & - & - \\
# 500 & 25 & Grad Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.20 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 25 & Grad TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.20 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 25 & LP Round & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.20 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 25 & LP TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.20 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 25 & Lang Round & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.19 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 25 & Lang TopK & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.20 \pm \scriptstyle{0.00}$ & - & $1.00 \pm \scriptstyle{0.00}$ & - \\
# 500 & 25 & Prob Grad & $0.00 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.90 \pm \scriptstyle{0.01}$ & $2.20 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 500 & 25 & Prob Lang & $0.05 \pm \scriptstyle{0.03}$ & $0.04 \pm \scriptstyle{0.01}$ & $0.05 \pm \scriptstyle{0.02}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.19 \pm \scriptstyle{0.00}$ & $-1.09 \pm \scriptstyle{0.02}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.01 \pm \scriptstyle{0.02}$ \\
# 500 & 25 & Prob Round & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.94 \pm \scriptstyle{0.00}$ & $2.19 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# \bottomrule
# \end{tabular}}
# \end{table}

# %%
pivot.columns = ["$N_{C}, N_{P}$", "k", "Method", "UAlloc Share", "OAlloc Share", "$U_{P}$Viol Share", "$\mathbb{E}[U_{G}]$", "$\mathbb{E}[{U_{C}}]$", "$\sigma(\mathbb{E}[U_{G}])$", "OAlloc Err", "$U_{P}$Viol Err", "UAlloc Err"]

# %%
# move columns to the end
pivot = pivot[["$N_{C}, N_{P}$", "k", "Method", "$\mathbb{E}[{U_{C}}]$", "$\mathbb{E}[U_{G}]$", "$\sigma(\mathbb{E}[U_{G}])$", "UAlloc Share", "OAlloc Share", "$U_{P}$Viol Share", "UAlloc Err",  "OAlloc Err", "$U_{P}$Viol Err"]]

# %%
# add \resizebox{\textwidth}{!}{\begin{tabular}
latex = pivot.to_latex()
latex = latex.replace(
    "\\begin{tabular}",
    "\\resizebox{\\textwidth}{!}{\\begin{tabular}"
).replace(
    "\\end{tabular}",
    "\\end{tabular}}"
)

print(latex)
# Out:
# \resizebox{\textwidth}{!}{\begin{tabular}{lrrllllllllll}
# \toprule
#  & $N_{C}, N_{P}$ & k & Method & $\mathbb{E}[{U_{C}}]$ & $\mathbb{E}[U_{G}]$ & $\sigma(\mathbb{E}[U_{G}])$ & UAlloc Share & OAlloc Share & $U_{P}$Viol Share & UAlloc Err & OAlloc Err & $U_{P}$Viol Err \\
# \midrule
# 0 & 200 & 10 & Baseline & $0.94 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 1 & 200 & 10 & Grad Round & $0.93 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & - & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 2 & 200 & 10 & Grad TopK & $0.93 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 3 & 200 & 10 & LP Round & $0.94 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 4 & 200 & 10 & LP TopK & $0.94 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 5 & 200 & 10 & Lang Round & $0.94 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.61 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 6 & 200 & 10 & Lang TopK & $0.94 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.62 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 7 & 200 & 15 & Baseline & $0.94 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 8 & 200 & 15 & Grad Round & $0.92 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & $-1.00 \pm \scriptstyle{0.00}$ & - \\
# 9 & 200 & 15 & Grad TopK & $0.92 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 10 & 200 & 15 & LP Round & $0.94 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 11 & 200 & 15 & LP TopK & $0.94 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 12 & 200 & 15 & Lang Round & $0.94 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.02 \pm \scriptstyle{0.01}$ & $0.02 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 13 & 200 & 15 & Lang TopK & $0.94 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.92 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 14 & 200 & 25 & Baseline & $0.93 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 15 & 200 & 25 & Grad Round & $0.91 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 16 & 200 & 25 & Grad TopK & $0.91 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 17 & 200 & 25 & LP Round & $0.93 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 18 & 200 & 25 & LP TopK & $0.93 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 19 & 200 & 25 & Lang Round & $0.93 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.53 \pm \scriptstyle{0.00}$ & $0.06 \pm \scriptstyle{0.02}$ & $0.03 \pm \scriptstyle{0.01}$ & $0.04 \pm \scriptstyle{0.01}$ & $1.06 \pm \scriptstyle{0.10}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 20 & 200 & 25 & Lang TopK & $0.93 \pm \scriptstyle{0.01}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.54 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.04 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 21 & 500 & 10 & Baseline & $0.95 \pm \scriptstyle{0.00}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 22 & 500 & 10 & Grad Round & $0.92 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 23 & 500 & 10 & Grad TopK & $0.92 \pm \scriptstyle{0.01}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 24 & 500 & 10 & LP Round & $0.95 \pm \scriptstyle{0.00}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & - \\
# 25 & 500 & 10 & LP TopK & $0.95 \pm \scriptstyle{0.00}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 26 & 500 & 10 & Lang Round & $0.94 \pm \scriptstyle{0.00}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 27 & 500 & 10 & Lang TopK & $0.94 \pm \scriptstyle{0.00}$ & $0.56 \pm \scriptstyle{0.00}$ & $0.59 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 28 & 500 & 15 & Baseline & $0.94 \pm \scriptstyle{0.00}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 29 & 500 & 15 & Grad Round & $0.90 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 30 & 500 & 15 & Grad TopK & $0.90 \pm \scriptstyle{0.01}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 31 & 500 & 15 & LP Round & $0.94 \pm \scriptstyle{0.00}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 32 & 500 & 15 & LP TopK & $0.94 \pm \scriptstyle{0.00}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 33 & 500 & 15 & Lang Round & $0.94 \pm \scriptstyle{0.00}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 34 & 500 & 15 & Lang TopK & $0.94 \pm \scriptstyle{0.00}$ & $0.83 \pm \scriptstyle{0.00}$ & $0.89 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 35 & 500 & 25 & Baseline & $0.94 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & - \\
# 36 & 500 & 25 & Grad Round & $0.92 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 37 & 500 & 25 & Grad TopK & $0.92 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 38 & 500 & 25 & LP Round & $0.94 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 39 & 500 & 25 & LP TopK & $0.94 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# 40 & 500 & 25 & Lang Round & $0.94 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.02 \pm \scriptstyle{0.02}$ & $0.01 \pm \scriptstyle{0.01}$ & $0.01 \pm \scriptstyle{0.01}$ & $1.00 \pm \scriptstyle{0.00}$ & $-1.00 \pm \scriptstyle{0.00}$ & $1.00 \pm \scriptstyle{0.00}$ \\
# 41 & 500 & 25 & Lang TopK & $0.94 \pm \scriptstyle{0.00}$ & $1.39 \pm \scriptstyle{0.00}$ & $1.48 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.00 \pm \scriptstyle{0.00}$ & $0.01 \pm \scriptstyle{0.01}$ & - & - & $1.00 \pm \scriptstyle{0.00}$ \\
# \bottomrule
# \end{tabular}}
